# %% [markdown]
# ## Importing libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from summarytools import dfSummary
from scipy import stats
import scipy.stats as stats
from sklearn.model_selection import train_test_split
from scipy.stats import spearmanr

# %% [markdown]
# ## Reading the data and overall Summary

# %%
churn_data = pd.read_csv("customer_churn_dataset-testing-master.csv")
churn_data
# Out:
#        CustomerID  Age  Gender  Tenure  Usage Frequency  Support Calls  \
# 0               1   22  Female      25               14              4
# 1               2   41  Female      28               28              7
# 2               3   47    Male      27               10              2
# 3               4   35    Male       9               12              5
# 4               5   53  Female      58               24              9
# ...           ...  ...     ...     ...              ...            ...
# 64369       64370   45  Female      33               12              6
# 64370       64371   37    Male       6                1              5
# 64371       64372   25    Male      39               14              8
# 64372       64373   50  Female      18               19              7
# 64373       64374   52  Female      45               15              9
#
#        Payment Delay Subscription Type Contract Length  Total Spend  \
# 0                 27             Basic         Monthly          598
# 1                 13          Standard         Monthly          584
# 2                 29           Premium          Annual          757
# 3                 17           Premium       Quarterly          232
# 4                  2          Standard          Annual          533
# ...              ...               ...             ...          ...
# 64369             21             Basic       Quarterly          947
# 64370             22          Standard          Annual          923
# 64371             30           Premium         Monthly          327
# 64372             22          Standard         Monthly          540
# 64373             25          Standard         Monthly          696
#
#        Last Interaction  Churn
# 0                     9      1
# 1                    20      0
# 2                    21      0
# 3                    18      0
# 4                    18      0
# ...                 ...    ...
# 64369                14      1
# 64370                 9      1
# 64371                20      1
# 64372                13      1
# 64373                22      1
#
# [64374 rows x 12 columns]

# %%
dfSummary(churn_data, is_collapsible=False)
# Out:
# <style type="text/css">
# #T_83a37 thead>tr>th {
#   text-align: left;
# }
# #T_83a37_row0_col0, #T_83a37_row1_col0, #T_83a37_row2_col0, #T_83a37_row3_col0, #T_83a37_row4_col0, #T_83a37_row5_col0, #T_83a37_row6_col0, #T_83a37_row7_col0, #T_83a37_row8_col0, #T_83a37_row9_col0, #T_83a37_row10_col0, #T_83a37_row11_col0 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 5%;
#   max-width: 50px;
#   min-width: 20px;
# }
# #T_83a37_row0_col1, #T_83a37_row1_col1, #T_83a37_row2_col1, #T_83a37_row3_col1, #T_83a37_row4_col1, #T_83a37_row5_col1, #T_83a37_row6_col1, #T_83a37_row7_col1, #T_83a37_row8_col1, #T_83a37_row9_col1, #T_83a37_row10_col1, #T_83a37_row11_col1 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 15%;
#   max-width: 200px;
#   min-width: 100px;
#   word-break: break-word;
# }
# #T_83a37_row0_col2, #T_83a37_row1_col2, #T_83a37_row2_col2, #T_83a37_row3_col2, #T_83a37_row4_col2, #T_83a37_row5_col2, #T_83a37_row6_col2, #T_83a37_row7_col2, #T_83a37_row8_col2, #T_83a37_row9_col2, #T_83a37_row10_col2, #T_83a37_row11_col2 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 30%;
#   min-width: 100px;
# }
# #T_83a37_row0_col3, #T_83a37_row1_col3, #T_83a37_row2_col3, #T_83a37_row3_col3, #T_83a37_row4_col3, #T_83a37_row5_col3, #T_83a37_row6_col3, #T_83a37_row7_col3, #T_83a37_row8_col3, #T_83a37_row9_col3, #T_83a37_row10_col3, #T_83a37_row11_col3 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 25%;
#   min-width: 100px;
# }
# #T_83a37_row0_col4, #T_83a37_row1_col4, #T_83a37_row2_col4, #T_83a37_row3_col4, #T_83a37_row4_col4, #T_83a37_row5_col4, #T_83a37_row6_col4, #T_83a37_row7_col4, #T_83a37_row8_col4, #T_83a37_row9_col4, #T_83a37_row10_col4, #T_83a37_row11_col4 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 20%;
#   min-width: 150px;
# }
# #T_83a37_row0_col5, #T_83a37_row1_col5, #T_83a37_row2_col5, #T_83a37_row3_col5, #T_83a37_row4_col5, #T_83a37_row5_col5, #T_83a37_row6_col5, #T_83a37_row7_col5, #T_83a37_row8_col5, #T_83a37_row9_col5, #T_83a37_row10_col5, #T_83a37_row11_col5 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 10%;
# }
# </style>
# <table id="T_83a37">
#   <caption><strong>Data Frame Summary</strong><br>_<br>Dimensions: 64,374 x 12<br>Duplicates: 0</caption>
#   <thead>
#     <tr>
#       <th id="T_83a37_level0_col0" class="col_heading level0 col0" >No</th>
#       <th id="T_83a37_level0_col1" class="col_heading level0 col1" >Variable</th>
#       <th id="T_83a37_level0_col2" class="col_heading level0 col2" >Stats / Values</th>
#       <th id="T_83a37_level0_col3" class="col_heading level0 col3" >Freqs / (% of Valid)</th>
#       <th id="T_83a37_level0_col4" class="col_heading level0 col4" >Graph</th>
#       <th id="T_83a37_level0_col5" class="col_heading level0 col5" >Missing</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_83a37_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_83a37_row0_col1" class="data row0 col1" ><strong>CustomerID</strong><br>[int64]</td>
#       <td id="T_83a37_row0_col2" class="data row0 col2" >Mean (sd) : 32187.5 (18583.3)<br>min < med < max:<br>1.0 < 32187.5 < 64374.0<br>IQR (CV) : 32186.5 (1.7)</td>
#       <td id="T_83a37_row0_col3" class="data row0 col3" >64,374 distinct values</td>
#       <td id="T_83a37_row0_col4" class="data row0 col4" ><img src = "......"></img></td>
#       <td id="T_83a37_row0_col5" class="data row0 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_83a37_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_83a37_row1_col1" class="data row1 col1" ><strong>Age</strong><br>[int64]</td>
#       <td id="T_83a37_row1_col2" class="data row1 col2" >Mean (sd) : 42.0 (13.9)<br>min < med < max:<br>18.0 < 42.0 < 65.0<br>IQR (CV) : 24.0 (3.0)</td>
#       <td id="T_83a37_row1_col3" class="data row1 col3" >48 distinct values</td>
#       <td id="T_83a37_row1_col4" class="data row1 col4" ><img src = "......"></img></td>
#       <td id="T_83a37_row1_col5" class="data row1 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_83a37_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_83a37_row2_col1" class="data row2 col1" ><strong>Gender</strong><br>[object]</td>
#       <td id="T_83a37_row2_col2" class="data row2 col2" >1. Female<br>2. Male</td>
#       <td id="T_83a37_row2_col3" class="data row2 col3" >34,353 (53.4%)<br>30,021 (46.6%)</td>
#       <td id="T_83a37_row2_col4" class="data row2 col4" ><img src = "......"></img></td>
#       <td id="T_83a37_row2_col5" class="data row2 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_83a37_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_83a37_row3_col1" class="data row3 col1" ><strong>Tenure</strong><br>[int64]</td>
#       <td id="T_83a37_row3_col2" class="data row3 col2" >Mean (sd) : 32.0 (17.1)<br>min < med < max:<br>1.0 < 33.0 < 60.0<br>IQR (CV) : 29.0 (1.9)</td>
#       <td id="T_83a37_row3_col3" class="data row3 col3" >60 distinct values</td>
#       <td id="T_83a37_row3_col4" class="data row3 col4" ><img src = "......"></img></td>
#       <td id="T_83a37_row3_col5" class="data row3 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_83a37_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_83a37_row4_col1" class="data row4 col1" ><strong>Usage Frequency</strong><br>[int64]</td>
#       <td id="T_83a37_row4_col2" class="data row4 col2" >Mean (sd) : 15.1 (8.8)<br>min < med < max:<br>1.0 < 15.0 < 30.0<br>IQR (CV) : 16.0 (1.7)</td>
#       <td id="T_83a37_row4_col3" class="data row4 col3" >30 distinct values</td>
#       <td id="T_83a37_row4_col4" class="data row4 col4" ><img src = "......"></img></td>
#       <td id="T_83a37_row4_col5" class="data row4 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_83a37_row5_col0" class="data row5 col0" >6</td>
#       <td id="T_83a37_row5_col1" class="data row5 col1" ><strong>Support Calls</strong><br>[int64]</td>
#       <td id="T_83a37_row5_col2" class="data row5 col2" >Mean (sd) : 5.4 (3.1)<br>min < med < max:<br>0.0 < 6.0 < 10.0<br>IQR (CV) : 5.0 (1.7)</td>
#       <td id="T_83a37_row5_col3" class="data row5 col3" >11 distinct values</td>
#       <td id="T_83a37_row5_col4" class="data row5 col4" ><img src = "......"></img></td>
#       <td id="T_83a37_row5_col5" class="data row5 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_83a37_row6_col0" class="data row6 col0" >7</td>
#       <td id="T_83a37_row6_col1" class="data row6 col1" ><strong>Payment Delay</strong><br>[int64]</td>
#       <td id="T_83a37_row6_col2" class="data row6 col2" >Mean (sd) : 17.1 (8.9)<br>min < med < max:<br>0.0 < 19.0 < 30.0<br>IQR (CV) : 15.0 (1.9)</td>
#       <td id="T_83a37_row6_col3" class="data row6 col3" >31 distinct values</td>
#       <td id="T_83a37_row6_col4" class="data row6 col4" ><img src = "......"></img></td>
#       <td id="T_83a37_row6_col5" class="data row6 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_83a37_row7_col0" class="data row7 col0" >8</td>
#       <td id="T_83a37_row7_col1" class="data row7 col1" ><strong>Subscription Type</strong><br>[object]</td>
#       <td id="T_83a37_row7_col2" class="data row7 col2" >1. Standard<br>2. Basic<br>3. Premium</td>
#       <td id="T_83a37_row7_col3" class="data row7 col3" >21,502 (33.4%)<br>21,451 (33.3%)<br>21,421 (33.3%)</td>
#       <td id="T_83a37_row7_col4" class="data row7 col4" ><img src = "......"></img></td>
#       <td id="T_83a37_row7_col5" class="data row7 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_83a37_row8_col0" class="data row8 col0" >9</td>
#       <td id="T_83a37_row8_col1" class="data row8 col1" ><strong>Contract Length</strong><br>[object]</td>
#       <td id="T_83a37_row8_col2" class="data row8 col2" >1. Monthly<br>2. Annual<br>3. Quarterly</td>
#       <td id="T_83a37_row8_col3" class="data row8 col3" >22,130 (34.4%)<br>21,410 (33.3%)<br>20,834 (32.4%)</td>
#       <td id="T_83a37_row8_col4" class="data row8 col4" ><img src = "......"></img></td>
#       <td id="T_83a37_row8_col5" class="data row8 col5" >0<br>(0.0%)</
